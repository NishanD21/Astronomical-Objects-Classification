# %% [markdown]
# ## Python Package testing

# %%
from skyndo.predict import predictor,plot_feature_distribution, plot_correlation_matrix,get_feature_descriptions, get_feature_names
import pandas as pd

data = pd.read_csv('Datasets/sgq_classification_zc_r.csv')

prediction = predictor(alpha=-0.05, delta=1.1, u=0.03, g=0.01, i=0.0, r=0.03, z=-0.002, redshift=-0.55)
print(f'Prediction: {prediction}')
# Out:
# Prediction: Galaxy
# c:\Users\Asus\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
get_feature_names()
# Out:
# ['alpha', 'delta', 'u', 'g', 'i', 'r', 'z', 'redshift']

# %%
get_feature_descriptions()
# Out:
# {'u': 'U-band (ultraviolet) magnitude',
#  'g': 'G-band (green) magnitude',
#  'r': 'R-band (red) magnitude',
#  'i': 'I-band (infrared) magnitude',
#  'z': 'Z-band (near-infrared) magnitude',
#  'redshift': 'Redshift (measure of the expansion of the universe)',
#  'ra': 'Right ascension (angular distance eastward along the celestial equator from the vernal equinox)',
#  'dec': 'Declination (angular distance north or south of the celestial equator)'}

# %%
plot_correlation_matrix(data)
